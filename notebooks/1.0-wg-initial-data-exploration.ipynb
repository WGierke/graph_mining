# %%
import pandas as pd
import json

path = '../data/raw/'
file_2006 = path + "HN_2006"
with open(file_2006) as f:
    file_2006_content = f.read()
file_2006_content = file_2006_content.rstrip()
file_2006_content = file_2006_content.replace('}\n{', '},{')
file_2006_content = "[{}]".format(file_2006_content)

df = pd.read_json(file_2006_content)
df
# Out:
#                by  dead  descendants  id                                 kids  \
# 0              pg   NaN         15.0   1  [487171, 15, 234509, 454410, 82729]
# 1         phyllis   NaN          0.0   2                             [454411]
# 2         phyllis   NaN          0.0   3                     [454412, 531602]
# 3     onebeerdave   NaN          0.0   4                             [454413]
# 4          perler   NaN          0.0   5                             [454414]
# 5          perler   NaN          0.0   6                             [454415]
# 6         phyllis   NaN          0.0   7                             [454416]
# 7      frobnicate   NaN          0.0   8                             [454417]
# 8        askjigga   NaN          0.0   9                             [454418]
# 9      frobnicate   NaN          0.0  10                             [454419]
# 10     frobnicate   NaN          0.0  11                             [454420]
# ...
